# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/dog.jpg', 0)        #  read image as gray scale  - 0

# %%
plt.imshow(img, cmap='gray')

# %%
plt.subplot( ) 
plt.imshow(img,cmap = 'Greys')
plt.subplot( )
plt.imshow(img,cmap = "Blues")

# %% [markdown]
# ## Sequential : Colormap

# %%
img = cv2.imread('images/dog.jpg',0)

# %%
origi_map = plt.colormaps['Greys'].reversed()

# %%
plt.figure(figsize=(16,16))
plt.subplot(441)
plt.imshow(img,cmap= plt.colormaps['Greys'].reversed()); 
plt.title('Greys')

plt.subplot(442)
plt.imshow(img,cmap= plt.colormaps['Blues'].reversed()); 
plt.title('Blues')

plt.subplot(443)
plt.imshow(img,cmap= plt.colormaps['Reds'].reversed()); 
plt.title('Reds')
plt.subplot(443)

plt.subplot(444)
plt.imshow(img,cmap= plt.colormaps['Greens'].reversed()); 
plt.title('Greens')
plt.subplot(444)

plt.subplot(445)
plt.imshow(img,cmap= plt.colormaps['Oranges'].reversed()); 
plt.title('Oranges')
plt.subplot(445)

plt.subplot(446)
plt.imshow(img,cmap= plt.colormaps['Purples'].reversed()); 
plt.title('Purples')
plt.subplot(446)

plt.subplot(447)
plt.imshow(img,cmap= plt.colormaps['PuRd'].reversed()); 
plt.title('PuRd')
plt.subplot(447)

plt.subplot(448)
plt.imshow(img,cmap= plt.colormaps['YlGn'].reversed()); 
plt.title('YlGn')
plt.subplot(448)
# Out:
# <Axes: title={'center': 'YlGn'}>

# %% [markdown]
# ## Diverging : Colormap

# %%
plt.figure(figsize=(16,16))
plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('PiYG')

plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('PRGn')

plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('BrBG')


plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('PuOr')


plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('RdGy')


plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('RdBu')


plt.subplot(  )
plt.imshow(img,cmap= '  '); plt.title('Spectral')


plt.subplot( )
plt.imshow(img,cmap= ' '); plt.title('coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 plt.figure(figsize=(16,16))
#       2 plt.subplot( )
# ----> 3 plt.imshow(img,cmap= ' '); plt.title('PiYG')
#       4
#       5 plt.subplot( )
#       6 plt.imshow(img,cmap= ' '); plt.title('PRGn')
#
# File ~\Desktop\NLP_Cv\.venv\Lib\site-packages\matplotlib\pyplot.py:3784, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3762 @_copy_docstring_and_deprecators(Axes.imshow)
#    3763 def imshow(
#    3764     X: ArrayLike | PIL.Image.Image,
#    (...)   3782     **kwargs,
#    3783 ) -> AxesImage:
# -> 3784     __ret = gca().imshow(
#    3785         X,
#    3786         cmap=cmap,
#    3787         norm=norm,
#    3788         aspect=aspect,
# ...

# %% [markdown]
# ## Cyclic : Colormap

# %%
plt.figure(figsize=(16,16))
plt.subplot(441)
plt.imshow(img,     ); plt.title('hsv')

plt.subplot( )
plt.imshow(     ); plt.title('twilight')

plt.subplot( )
plt.imshow(  ); plt.title('twilight_shifted')
plt.subplot( )

plt.subplot( )
plt.imshow( ); plt.title('viridis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2 plt.subplot(441)
#       3 plt.imshow(img,     ); plt.title('hsv')
#       4
#       5 plt.subplot( )
# ----> 6 plt.imshow(     ); plt.title('twilight')
#       7
#       8 plt.subplot( )
#       9 plt.imshow(  ); plt.title('twilight_shifted')
#
# TypeError: imshow() missing 1 required positional argument: 'X'
