# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = {
    "text": [
        "The phone is excellent",
        "I love this phone",
        "The camera quality is amazing",
        "This laptop works perfectly",
        "The phone is terrible",
        "I hate this phone",
        "The camera quality is poor",
        "This laptop is very slow"
    ],

    "label": [
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative"
    ]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#                             text     label
# 0         The phone is excellent  positive
# 1              I love this phone  positive
# 2  The camera quality is amazing  positive
# 3    This laptop works perfectly  positive
# 4          The phone is terrible  negative
# 5              I hate this phone  negative
# 6     The camera quality is poor  negative
# 7       This laptop is very slow  negative

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df ["text"])
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 33 stored elements and shape (8, 17)>
#   Coords	Values
#   (0, 13)	0.4355765442986997
#   (0, 8)	0.4355765442986997
#   (0, 4)	0.3855603831764714
#   (0, 2)	0.6869420201431985
#   (1, 8)	0.47207624983025376
#   (1, 6)	0.7445052240867136
#   (1, 14)	0.47207624983025376
#   (2, 13)	0.35887202731956774
#   (2, 4)	0.3176636533251056
#   (2, 1)	0.4743289909406755
#   (2, 10)	0.4743289909406755
#   (2, 0)	0.5659723386086033
#   (3, 14)	0.35987631398049097
#   (3, 5)	0.47565637853911513
#   (3, 16)	0.5675561858489735
#   (3, 7)	0.5675561858489735
#   (4, 13)	0.4355765442986997
#   (4, 8)	0.4355765442986997
#   (4, 4)	0.3855603831764714
#   (4, 12)	0.6869420201431985
#   (5, 8)	0.47207624983025376
#   (5, 14)	0.47207624983025376
#   (5, 3)	0.7445052240867136
#   (6, 13)	0.35887202731956774
#   (6, 4)	0.3176636533251056
#   (6, 1)	0.4743289909406755
#   (6, 10)	0.4743289909406755
#   (6, 9)	0.5659723386086033
#   (7, 4)	0.3035244685250475
#   (7, 14)	0.34289866095948923
#   (7, 5)	0.45321664400159534
#   (7, 15)	0.5407809533067468
#   (7, 11)	0.5407809533067468
