# %%
import nltk

# Download only WordNet data
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk

from nltk.corpus import wordnet

word = "book"
#word = "bank"

# Find meanings of the word
# Synset = Set of synonyms representing one particular meaning.
synsets = wordnet.synsets(word)
print(synsets)

print("Number of meanings:", len(synsets))

for synset in synsets:
    print("\nSynset:", synset)
    print("Definition:", synset.definition())
    print("Examples:", synset.examples())
# Out:
# [Synset('book.n.01'), Synset('book.n.02'), Synset('record.n.05'), Synset('script.n.01'), Synset('ledger.n.01'), Synset('book.n.06'), Synset('book.n.07'), Synset('koran.n.01'), Synset('bible.n.01'), Synset('book.n.10'), Synset('book.n.11'), Synset('book.v.01'), Synset('reserve.v.04'), Synset('book.v.03'), Synset('book.v.04')]
# Number of meanings: 15
#
# Synset: Synset('book.n.01')
# Definition: a written work or composition that has been published (printed on pages bound together)
# Examples: ['I am reading a good book on economics']
#
# Synset: Synset('book.n.02')
# Definition: physical objects consisting of a number of pages bound together
# Examples: ['he used a large book as a doorstop']
#
# Synset: Synset('record.n.05')
# Definition: a compilation of the known facts regarding something or someone
# Examples: ["Al Smith used to say, `Let's look at the record'", 'his name is in all the record books']
#
# Synset: Synset('script.n.01')
# ...

# %%
# synonyms

import nltk

from nltk.corpus import wordnet

word = "happy"

synonyms = set()

# Find synsets
for synset in wordnet.synsets(word):

    # Find words in each synset
    for lemma in synset.lemmas():

        synonyms.add(lemma.name())

print("Synonyms:")
print(synonyms)
# Out:
# Synonyms:
# {'well-chosen', 'happy', 'glad', 'felicitous'}

# %%
# Antonyms

import nltk

from nltk.corpus import wordnet

word = "good"

antonyms = set()

for synset in wordnet.synsets(word):

    for lemma in synset.lemmas():

        for antonym in lemma.antonyms():

            antonyms.add(antonym.name())

print("Antonyms:")
print(antonyms)
# Out:
# Antonyms:
# {'ill', 'evil', 'bad', 'badness', 'evilness'}

# %%
# Hypernyms

import nltk

from nltk.corpus import wordnet

word = "dog"

synsets = wordnet.synsets(word)

for synset in synsets:

    print("\nSynset:", synset)

    hypernyms = synset.hypernyms()

    print("Hypernyms:")

    for hypernym in hypernyms:
        print(hypernym)
# Out:
# Synset: Synset('dog.n.01')
# Hypernyms:
# Synset('domestic_animal.n.01')
# Synset('canine.n.02')
#
# Synset: Synset('frump.n.01')
# Hypernyms:
# Synset('unpleasant_woman.n.01')
#
# Synset: Synset('dog.n.03')
# Hypernyms:
# Synset('chap.n.01')
#
# Synset: Synset('cad.n.01')
# Hypernyms:
# Synset('villain.n.01')
#
# Synset: Synset('frank.n.02')
# Hypernyms:
# Synset('sausage.n.01')
#
# Synset: Synset('pawl.n.01')
# Hypernyms:
# Synset('catch.n.06')
#
# Synset: Synset('andiron.n.01')
# Hypernyms:
# Synset('support.n.10')
#
# Synset: Synset('chase.v.01')
# Hypernyms:
# Synset('pursue.v.02')

# %%
# Hyponyms
import nltk

from nltk.corpus import wordnet

word = "animal"

synset = wordnet.synsets(word)[0]

print("Word:", synset)

print("\nHyponyms:")

for hyponym in synset.hyponyms():
    print(hyponym)
# Out:
# Word: Synset('animal.n.01')
#
# Hyponyms:
# Synset('feeder.n.06')
# Synset('predator.n.02')
# Synset('molter.n.01')
# Synset('female.n.01')
# Synset('metazoan.n.01')
# Synset('captive.n.02')
# Synset('racer.n.03')
# Synset('hexapod.n.01')
# Synset('thoroughbred.n.03')
# Synset('chordate.n.01')
# Synset('critter.n.01')
# Synset('survivor.n.03')
# Synset('mate.n.03')
# Synset('darter.n.02')
# Synset('poikilotherm.n.01')
# Synset('pleurodont.n.01')
# Synset('young.n.01')
# Synset('biped.n.01')
# Synset('pest.n.04')
# Synset('stayer.n.01')
# Synset('stunt.n.02')
# Synset('zooplankton.n.01')
# Synset('pet.n.01')
# Synset('larva.n.01')
# Synset('acrodont.n.01')
# Synset('creepy-crawly.n.01')
# Synset('giant.n.01')
# Synset('homeotherm.n.01')
# Synset('varmint.n.02')
# Synset('marine_animal.n.01')
# Synset('adult.n.02')
# Synset('scavenger.n.03')
# Synset('male.n.01')
# Synset('embryo.n.02')
# Synset('migrator.n.02')
# Synset('invertebrate.n.01')
# Synset('mutant.n.02')
# ...

# %%
#Meronym

from nltk.corpus import wordnet as wn

word = "car"

syn = wn.synsets(word)[0]

print("Word:", word)
print("Synset:", syn.name())
print("Definition:", syn.definition())

print("\nParts (Meronyms):")

for part in syn.part_meronyms():
    print(part.name())
# Out:
# Word: car
# Synset: car.n.01
# Definition: a motor vehicle with four wheels; usually propelled by an internal combustion engine
#
# Parts (Meronyms):
# air_bag.n.01
# automobile_engine.n.01
# roof.n.02
# gasoline_engine.n.01
# auto_accessory.n.01
# sunroof.n.01
# automobile_horn.n.01
# rear_window.n.01
# buffer.n.06
# fender.n.01
# glove_compartment.n.01
# car_window.n.01
# floorboard.n.02
# accelerator.n.01
# grille.n.02
# car_mirror.n.01
# first_gear.n.01
# car_door.n.01
# reverse.n.02
# stabilizer_bar.n.01
# bumper.n.02
# car_seat.n.01
# high_gear.n.01
# window.n.02
# tail_fin.n.02
# third_gear.n.01
# running_board.n.01
# hood.n.09
# luggage_compartment.n.01

# %%
# Word Similarity

import nltk

from nltk.corpus import wordnet

# A higher value indicates greater similarity according to the Wu-Palmer similarity measure. (value between 0 and 1)

dog = wordnet.synsets("dog")[0]
cat = wordnet.synsets("cat")[0]

similarity = dog.wup_similarity(cat)

print("Similarity:", similarity)
# Out:
# Similarity: 0.8571428571428571

# %%
# Complete wordnet

import nltk

# Download only WordNet resources
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import wordnet

word = "happy"

print("Word:", word)

# Find meanings
synsets = wordnet.synsets(word)

print("\n--- Meanings ---")

for synset in synsets:

    print("\nSynset:", synset)
    print("Definition:", synset.definition())
    print("Examples:", synset.examples())


# Find synonyms
synonyms = set()

for synset in synsets:

    for lemma in synset.lemmas():

        synonyms.add(lemma.name())

print("\n--- Synonyms ---")
print(synonyms)


# Find antonyms
antonyms = set()

for synset in synsets:

    for lemma in synset.lemmas():

        for antonym in lemma.antonyms():

            antonyms.add(antonym.name())

print("\n--- Antonyms ---")
print(antonyms)
# Out:
# Word: happy
#
# --- Meanings ---
#
# Synset: Synset('happy.a.01')
# Definition: enjoying or showing or marked by joy or pleasure
# Examples: ['a happy smile', 'spent many happy days on the beach', 'a happy marriage']
#
# Synset: Synset('felicitous.s.01')
# Definition: marked by good fortune
# Examples: ['a felicitous life', 'a happy outcome']
#
# Synset: Synset('glad.s.01')
# Definition: eagerly disposed to act or to be of service
# Examples: ['glad to help']
#
# Synset: Synset('happy.s.03')
# Definition: well expressed and to the point
# Examples: ['a happy turn of phrase', 'a few well-chosen words']
#
# --- Synonyms ---
# {'well-chosen', 'happy', 'glad', 'felicitous'}
#
# --- Antonyms ---
# {'unhappy'}
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# ...

# %%
# WordNet and Lemmatization

import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = [
    "cars",
    "studies",
    "playing",
    "better"
]

for word in words:

    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# cars -> car
# studies -> study
# playing -> playing
# better -> better
