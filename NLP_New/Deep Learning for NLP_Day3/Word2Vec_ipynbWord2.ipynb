# %%
#pip install gensim

# %% [markdown]
# ## Import Necessary Libraries

# %%
import gensim
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
corpus_text = [
    # --- TOPIC 1: FOOD & FRUITS ---
    "I eat mango and apple everyday",
    "Mango is a very sweet and delicious fruit",
    "Apple pie is a tasty dessert",
    "Banana is yellow and good for health",
    "Fruits like mango apple and banana are healthy",
    "I love eating pizza and burger for dinner",
    "Burger is a fast food",
    "Pizza contains cheese and tomato sauce",
    "I am hungry I want to eat food",
    "Restaurant serves delicious meals",
    "Vegetables and fruits are essential for diet",
    "Cook dinner in the kitchen",
    "Sweet desserts like cake and chocolate",

    # --- TOPIC 2: SPORTS & GAMES ---
    "Cricket is a popular sport in India",
    "Virat Kohli plays cricket for the team",
    "Football is played with a ball in a stadium",
    "Messi is a famous football player",
    "Players run fast to score a goal",
    "Tennis is played with a racket and ball",
    "The match was played in a big stadium",
    "The team won the championship trophy",
    "Athletes run in the olympics",
    "Bat and ball are used in cricket matches",
    "Score runs to win the cricket game",
    "The referee blew the whistle",

    # --- TOPIC 3: TECHNOLOGY & CODING ---
    "Python is a popular programming language",
    "Computers use binary code to process data",
    "Artificial Intelligence and machine learning are the future",
    "Data science involves statistics and algorithms",
    "Software developers write code in java and python",
    "The computer requires a keyboard and mouse",
    "Internet connects computers globally",
    "Deep learning models use neural networks",
    "Robots are built using engineering and ai",
    "The server stores massive amounts of data",
    "Programmers debug the software code",
    "Technology is advancing rapidly"
]

# %% [markdown]
# ## Preprocessing with gensim

# %%
tokenized_text = []
for sent in corpus_text :
  tokens = gensim.utils.simple_preprocess(sent)
  tokenized_text.append(tokens)

# %%
tokenized_text
# Out:
# [['eat', 'mango', 'and', 'apple', 'everyday'],
#  ['mango', 'is', 'very', 'sweet', 'and', 'delicious', 'fruit'],
#  ['apple', 'pie', 'is', 'tasty', 'dessert'],
#  ['banana', 'is', 'yellow', 'and', 'good', 'for', 'health'],
#  ['fruits', 'like', 'mango', 'apple', 'and', 'banana', 'are', 'healthy'],
#  ['love', 'eating', 'pizza', 'and', 'burger', 'for', 'dinner'],
#  ['burger', 'is', 'fast', 'food'],
#  ['pizza', 'contains', 'cheese', 'and', 'tomato', 'sauce'],
#  ['am', 'hungry', 'want', 'to', 'eat', 'food'],
#  ['restaurant', 'serves', 'delicious', 'meals'],
#  ['vegetables', 'and', 'fruits', 'are', 'essential', 'for', 'diet'],
#  ['cook', 'dinner', 'in', 'the', 'kitchen'],
#  ['sweet', 'desserts', 'like', 'cake', 'and', 'chocolate'],
#  ['cricket', 'is', 'popular', 'sport', 'in', 'india'],
#  ['virat', 'kohli', 'plays', 'cricket', 'for', 'the', 'team'],
#  ['football', 'is', 'played', 'with', 'ball', 'in', 'stadium'],
#  ['messi', 'is', 'famous', 'football', 'player'],
#  ['players', 'run', 'fast', 'to', 'score', 'goal'],
#  ['tennis', 'is', 'played', 'with', 'racket', 'and', 'ball'],
#  ['the', 'match', 'was', 'played', 'in', 'big', 'stadium'],
#  ['the', 'team', 'won', 'the', 'championship', 'trophy'],
#  ['athletes', 'run', 'in', 'the', 'olympics'],
#  ['bat', 'and', 'ball', 'are', 'used', 'in', 'cricket', 'matches'],
#  ['score', 'runs', 'to', 'win', 'the', 'cricket', 'game'],
#  ['the', 'referee', 'blew', 'the', 'whistle'],
#  ['python', 'is', 'popular', 'programming', 'language'],
#  ['computers', 'use', 'binary', 'code', 'to', 'process', 'data'],
#  ['artificial',
#   'intelligence',
#   'and',
#   'machine',
#   'learning',
#   'are',
#   'the',
#   'future'],
#  ['data', 'science', 'involves', 'statistics', 'and', 'algorithms'],
#  ['software', 'developers', 'write', 'code', 'in', 'java', 'and', 'python'],
#  ['the', 'computer', 'requires', 'keyboard', 'and', 'mouse'],
#  ['internet', 'connects', 'computers', 'globally'],
#  ['deep', 'learning', 'models', 'use', 'neural', 'networks'],
#  ['robots', 'are', 'built', 'using', 'engineering', 'and', 'ai'],
#  ['the', 'server', 'stores', 'massive', 'amounts', 'of', 'data'],
#  ['programmers', 'debug', 'the', 'software', 'code'],
#  ['technology', 'is', 'advancing', 'rapidly']]

# %% [markdown]
# ## Word 2 Vec

# %%
model = Word2Vec(sentences = tokenized_text,
                 epochs=1000,vector_size=40,#change the vector_size,epoch
                 window = 5, #5words after and 5words before
                 sg = 1, min_count = 1,
                 ) #ski[ gram min_count--> add or remove list base on frequency

# %% [markdown]
# ## Using the model

# %%
model.wv['mango']
# Out:
# array([-0.20003149,  0.7514644 ,  0.29814044,  0.5288324 , -1.1525034 ,
#        -0.56013083,  0.8827274 , -0.8852048 , -0.14001656,  0.12583886,
#         0.54309046, -0.83785135,  0.55685174, -0.13245869,  0.29468855,
#         0.03494947,  0.3382498 ,  0.47953382,  0.04653803, -0.60577226,
#         0.29052782, -0.12900531,  0.04294007,  0.16575487, -0.32386482,
#        -0.28909063, -0.08569732,  0.256574  , -0.8514732 , -0.9486836 ,
#        -0.15359248, -0.12103783,  0.6737947 ,  0.13233218, -0.12090616,
#         0.10411184,  1.1822811 , -0.5423841 , -0.61204654, -0.05746129],
#       dtype=float32)

# %%
model.wv['programming']
# Out:
# array([-3.2820810e-02, -3.6311921e-01, -1.0886419e-03, -3.6902279e-01,
#        -6.1407655e-01, -7.2402924e-01,  2.1922089e-01,  4.3560189e-01,
#        -5.2219963e-01,  2.7878878e-01,  3.3588701e-01, -2.1467587e-01,
#         6.6673040e-01, -3.2378830e-02,  4.3243739e-01,  9.4493854e-01,
#        -8.6902224e-02,  3.1414721e-02, -9.0420628e-01, -6.8634176e-01,
#         6.4031869e-01, -6.6588295e-01,  1.5540069e+00,  1.4413507e-01,
#        -3.9542034e-01, -7.7561200e-01, -6.0983551e-01,  6.3204044e-01,
#         2.0339902e-01, -5.4687083e-01,  2.3050107e-01, -1.9203769e-01,
#         1.4479344e+00,  2.0860936e-01,  9.6846509e-01,  1.2621380e-01,
#         2.3162843e-01, -7.9722703e-02, -4.5135897e-01, -5.6222755e-02],
#       dtype=float32)

# %%
model.wv.most_similar('mango')
# Out:
# [('everyday', 0.875492513179779),
#  ('healthy', 0.8707572221755981),
#  ('apple', 0.8365341424942017),
#  ('fruit', 0.8215633034706116),
#  ('very', 0.8074203729629517),
#  ('like', 0.7868357300758362),
#  ('sweet', 0.7607471942901611),
#  ('banana', 0.7603741884231567),
#  ('fruits', 0.7539060115814209),
#  ('eat', 0.7390022277832031)]

# %%
model.wv.most_similar('cricket')
# Out:
# [('plays', 0.7578064203262329),
#  ('kohli', 0.7571104168891907),
#  ('virat', 0.7531635761260986),
#  ('game', 0.7480983138084412),
#  ('india', 0.738332211971283),
#  ('sport', 0.7279756665229797),
#  ('runs', 0.7263463139533997),
#  ('win', 0.7257951498031616),
#  ('bat', 0.7173417806625366),
#  ('matches', 0.7088201642036438)]

# %%
np.dot(model.wv['fruit'], model.wv['banana'])
# Out:
# np.float32(6.9119353)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([model.wv['fruit'], model.wv['banana']])
# Out:
# array([[1.        , 0.58391404],
#        [0.58391404, 0.9999998 ]], dtype=float32)

# %%
cosine_similarity([model.wv['computer']], [model.wv['science']])
# Out:
# array([[0.43831855]], dtype=float32)

# %%
cosine_similarity([model.wv['played']], [model.wv['ball']])
# Out:
# array([[0.83145565]], dtype=float32)

# %%
cosine_similarity([model.wv['pizza']], [model.wv['burger']])
# Out:
# array([[0.81189483]], dtype=float32)

# %%
list1=['mango','banana','football']

# %%
model.wv.doesnt_match(list1)#training data quality
# Out:
# 'football'

# %%
words_of_interest =[ 'apple','banana','fruit',
                    'burger','pizza','cricket','football',
                     'tennis','player','ball','python','java','computer','code',
                     'software']

# %%
vectors = [model.wv[w] for w in words_of_interest]

# %%
len(vectors)
# Out:
# 15

# %%
vector = np.array(vectors)

# %%
vector.shape
# Out:
# (15, 40)

# %% [markdown]
# ## Reduce the dimenstions of these vectors to 2

# %%
pca = PCA(n_components=2)

# %%
vectors_2d = pca.fit_transform(vectors)
vectors_2d.shape
# Out:
# (15, 2)

# %%
plt.figure(figsize =(16,9)) # width and high (8,6)
plt.scatter(vectors_2d[:,0], vectors_2d[:,1], color = 'r')# x-axis PC1 # y-axis PC2
for i , word in enumerate(words_of_interest):
  plt.annotate(word,xy=(vectors_2d[i,0],vectors_2d[i,1]),
               ha='right',va='bottom') #horizontal alignment and vertical alignment
plt.grid()

# %%
gensim.__version__
# Out:
# '4.4.0'
