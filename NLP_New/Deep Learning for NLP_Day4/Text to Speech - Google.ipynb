# %%
pip install gtts playsound
# Out:
# Requirement already satisfied: gtts in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.5.4)
# Requirement already satisfied: playsound in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.2)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gtts) (2.32.5)
# Requirement already satisfied: click<8.2,>=7.1 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gtts) (8.1.8)
# Requirement already satisfied: colorama in C:\Users\MOE0157\AppData\Roaming\Python\Python313\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.27->gtts) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.27->gtts) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.27->gtts) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.27->gtts) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
from playsound import playsound
# Out:
# C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (7.5.1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
# create the object of gtts
#

# %%
# save the audio
#
#

# %%
tts1 = gTTS("नमस्कार, पायथॉनच्या विश्वामध्ये तुमचे स्वागत आहे!", lang='mr')

# %%
# save the audio
tts1.save('C:/Users/MOE0157/NLP/Day10/audio1.mp3')
playsound('C:/Users/MOE0157/NLP/Day10/audio1.mp3')
