# %%
import nltk
import random

# %% [markdown]
# #define the chatbot responses and intents

# %%
responses = {
    'greeting':['Hello!', 'Hi there !', ' Hey!','Howdy!'],
    'goodbye' :['Good bye!', 'See you later!',' Take Care','Bye!'],
    'thanks' : ['You\'re welcome!', 'Glad to help!', 'My pleasure!','Anytime'],
    'default' :['Sorry I didnt understand','Can you tell again?','I am not sure']
}

# %% [markdown]
# # simple set of questions and responses or patterns

# %%
patterns = {
    'hi': 'greeting',
    'hello':'greeting',
    'hey' : 'goodbye',
    'bye': 'goodbye',
    'thanks': 'thanks',
    'thank you':'thanks'
}

# %% [markdown]
# # Match the user input

# %%
def respond(user_input):
    for word in nltk.tokenize.word_tokenize(user_input.lower()):
        if word in patterns:
          intent = patterns[word]
          return random.choice(responses[intent])
    return random.choice(responses['default'])

# %%
respond('hi')
# Out:
# 'Hi there !'

# %%
respond('hi')
# Out:
# 'Hello!'

# %%
respond('hi')
# Out:
# 'Hi there !'

# %%
def chat():
  print('Chatbot: How can I help you today?(Type " exit" to quit)')
  while True:
    user_input = input('You: ')
    if user_input == 'exit':
      print('Chatbot : Good Bye!')
      break
    response = respond(user_input)
    print('Chatbot:', response)

# %%
chat()
# Out:
# Chatbot: How can I help you today?(Type " exit" to quit)
# Chatbot: Howdy!
# Chatbot: See you later!
# Chatbot: You're welcome!
# Chatbot: Sorry I didnt understand
# Chatbot : Good Bye!
