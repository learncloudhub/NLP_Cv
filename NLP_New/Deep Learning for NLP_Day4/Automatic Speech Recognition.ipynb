# %%
pip install speechrecognition pyttsx3
# Out:
# Requirement already satisfied: speechrecognition in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.17.0)
# Requirement already satisfied: pyttsx3 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.99)
# Requirement already satisfied: typing-extensions in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (4.15.0)
# Requirement already satisfied: standard-aifc in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from speechrecognition) (0.2.2)
# Requirement already satisfied: comtypes in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (1.4.16)
# Requirement already satisfied: pypiwin32 in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in C:\Users\MOE0157\AppData\Roaming\Python\Python313\site-packages (from pyttsx3) (311)
# Requirement already satisfied: standard-chunk in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (from standard-aifc->speechrecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### TTS

# %%
import pyttsx3

# %%
engine = pyttsx3.init()

# %%
# Set the properties
#
#

# %%
text = 'Welcome to world of Deep Learning using Python Programming.'

# %%
#
#

# %%
pip install pyaudio -U
# Out:
# Requirement already satisfied: pyaudio in C:\Users\MOE0157\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### ASR

# %%
import speech_recognition as sr

# %%
#

# %%
with sr.Microphone() as source:
    #
    print('Speak:')
    #
    #
# Out:
# Speak:
# You said: hello
