# %%
import nltk

# %%
# sentence = """At eight o'clock on Thursday morning..... Arthur didn't feel very good."""

# %%
sentence = """သူသွားမယ် သို့မဟုတ် သူလာမယ်။"""

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['သူသွားမယ်', 'သို့မဟုတ်', 'သူလာမယ်။']

# %%
tagged = nltk.pos_tag(tokens)
tagged[0:6]
# Out:
# [('သူသွားမယ်', 'JJ'), ('သို့မဟုတ်', 'NNP'), ('သူလာမယ်။', 'NN')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# Tree('S', [('သူသွားမယ်', 'JJ'), ('သို့မဟုတ်', 'NNP'), ('သူလာမယ်။', 'NN')])

# %%
import string

def remove_punctuation(text):
    return text.translate(
        str.maketrans('', '', string.punctuation)
    )

text = "I love NLP! Python is great. @AI #MachineLearning"

clean_text = remove_punctuation(text)

print(clean_text)
# Out:
# I love NLP Python is great AI MachineLearning

# %%
import re

def remove_urls(text):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

text = """
I love NLP.
Visit https://www.google.com
Also check www.example.com
"""

clean_text = remove_urls(text)

print(clean_text)
# Out:
# I love NLP.
# Visit
# Also check
