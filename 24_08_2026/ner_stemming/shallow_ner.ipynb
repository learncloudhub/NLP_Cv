# %%
# in Bash     python -m pip install numpy       (NLTK works with numpy in NER)
import nltk

from nltk.tokenize import word_tokenize

# Required resources
'''
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
'''

# NER resources
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

text = "John works at Microsoft in London."

# Step 1: Tokenization
tokens = word_tokenize(text)

# Step 2: POS tagging
tags = nltk.pos_tag(tokens)

# Step 3: Named Entity Recognition
entities = nltk.ne_chunk(tags)

# Display result
print(entities)

# Display tree
entities.pretty_print()
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\UserH\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON John/NNP)
#   works/VBZ
#   at/IN
#   (ORGANIZATION Microsoft/NNP)
#   in/IN
#   (GPE London/NNP)
#   ./.)
#                        S
#      __________________|_____________________________
#     |       |     |    |   PERSON   ORGANIZATION    GPE
#     |       |     |    |     |           |           |
# works/VBZ at/IN in/IN ./. John/NNP Microsoft/NNP London/NNP
