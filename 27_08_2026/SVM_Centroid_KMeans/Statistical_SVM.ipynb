# %%
# ============================================================
# Step 1: Import Libraries
# ============================================================

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
# ============================================================
# Step 2: Create Dataset
# ============================================================

data = {
    "text": [
        "I love this movie",
        "This movie is amazing",
        "I like this product",
        "This is excellent",
        "I hate this movie",
        "This movie is terrible",
        "I dislike this product",
        "This is bad"
    ],

    "label": [
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative"
    ]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)
# Out:
# Dataset:
#                      text     label
# 0       I love this movie  positive
# 1   This movie is amazing  positive
# 2     I like this product  positive
# 3       This is excellent  positive
# 4       I hate this movie  negative
# 5  This movie is terrible  negative
# 6  I dislike this product  negative
# 7             This is bad  negative

# %%
# ============================================================
# Step 3: Separate X and y
# ============================================================

X = df["text"]
y = df["label"]

print("\nX:")
print(X)

print("\ny:")
print(y)
# Out:
# X:
# 0         I love this movie
# 1     This movie is amazing
# 2       I like this product
# 3         This is excellent
# 4         I hate this movie
# 5    This movie is terrible
# 6    I dislike this product
# 7               This is bad
# Name: text, dtype: str
#
# y:
# 0    positive
# 1    positive
# 2    positive
# 3    positive
# 4    negative
# 5    negative
# 6    negative
# 7    negative
# Name: label, dtype: str

# %%
# ============================================================
# Step 4: Split Data
# ============================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42         # Keep the same data split
)

print("\nTraining Data:")
print(X_train)

print("\nTesting Data:")
print(X_test)
# Out:
# Training Data:
# 0         I love this movie
# 7               This is bad
# 2       I like this product
# 4         I hate this movie
# 3         This is excellent
# 6    I dislike this product
# Name: text, dtype: str
#
# Testing Data:
# 1     This movie is amazing
# 5    This movie is terrible
# Name: text, dtype: str

# %%
# ============================================================
# Step 5: Convert Text to TF-IDF
# ============================================================

tfidf = TfidfVectorizer()

X_train_tfidf = tfidf.fit_transform(X_train)    # Learn + convert training data

X_test_tfidf = tfidf.transform(X_test)          # Convert test data

print("\nTraining TF-IDF Shape:")
print(X_train_tfidf.shape)                      # training documents, TF-IDF features

print("\nTesting TF-IDF Shape:")
print(X_test_tfidf.shape)                       # testing documents, TF-IDF features
# Out:
# Training TF-IDF Shape:
# (6, 10)
#
# Testing TF-IDF Shape:
# (2, 10)

# %%
# ============================================================
# Step 6: Create SVM Model
# ============================================================

svm_model = SVC(
    kernel="linear"
)

# %%
# ============================================================
# Step 7: Train Model
# ============================================================

svm_model.fit(
    X_train_tfidf,
    y_train
)

print("\nModel trained.")
# Out:
# Model trained.

# %%
# ============================================================
# Step 8: Make Predictions
# ============================================================

y_pred = svm_model.predict(
    X_test_tfidf
)

print("\nActual Labels:")
print(y_test.values)

print("\nPredicted Labels:")
print(y_pred)
# Out:
# Actual Labels:
# <StringArray>
# ['positive', 'negative']
# Length: 2, dtype: str
#
# Predicted Labels:
# ['positive' 'positive']

# %%
# ============================================================
# Step 9: Evaluate Model
# ============================================================

accuracy = accuracy_score(
    y_test,
    y_pred
)

print("\nAccuracy:")
print(accuracy)
# Out:
# Accuracy:
# 0.5

# %%
# ============================================================
# Step 10: Predict New Text
# ============================================================

new_text = [
    "This movie is wonderful"
]

new_vector = tfidf.transform(
    new_text
)

prediction = svm_model.predict(
    new_vector
)

print("\nNew Text:")
print(new_text)

print("\nPrediction:")
print(prediction)
# Out:
# New Text:
# ['This movie is wonderful']
#
# Prediction:
# ['positive']

# %%
"""
Dataset
   ↓
X and y
   ↓
Train / Test Split
   ↓
TF-IDF
   ↓
SVM
   ↓
Training
   ↓
Prediction
   ↓
Evaluation
   ↓
New Sentence
"""
# Out:
# '\nDataset\n   ↓\nX and y\n   ↓\nTrain / Test Split\n   ↓\nTF-IDF\n   ↓\nSVM\n   ↓\nTraining\n   ↓\nPrediction\n   ↓\nEvaluation\n   ↓\nNew Sentence\n'
